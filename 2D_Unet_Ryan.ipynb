# %% [markdown]
# <a href="https://colab.research.google.com/github/haozhi-ryan/PatternAnalysis-2025/blob/topic-recognition/2D_Unet_Ryan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
print('goodbye')
